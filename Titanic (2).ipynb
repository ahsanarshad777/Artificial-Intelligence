# %%
import pandas as pd
import numpy as np
dataFrame = pd.read_csv (r'tested.csv')

# %%
dataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# #### **Before** imputing Total **null values (missing Values)**

# %%
na = dataFrame.isna( ).sum()
na
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# #### **Removing Cabin Column in Dataset.**

# %%
dataFrame = dataFrame.drop(columns= 'Cabin', axis=1)
dataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### **Taking Care of missing Data**

# %% [markdown]
# #### Imputing **Age** And **Fare** with **Mean Values**

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(dataFrame[['Age','Fare']])
dataFrame[['Age','Fare']] = imputer.transform(dataFrame[['Age','Fare']])

# %%
dataFrame[['Age','Fare']]
# Out:
#           Age      Fare
# 0    34.50000    7.8292
# 1    47.00000    7.0000
# 2    62.00000    9.6875
# 3    27.00000    8.6625
# 4    22.00000   12.2875
# ..        ...       ...
# 413  30.27259    8.0500
# 414  39.00000  108.9000
# 415  38.50000    7.2500
# 416  30.27259    8.0500
# 417  30.27259   22.3583
#
# [418 rows x 2 columns]

# %% [markdown]
# #### **After** imputing Total **null values (missing Values)**

# %%
na = dataFrame.isna( ).sum()
na
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
dataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %% [markdown]
# #### **Converting Age column float to integer**

# %%
dataFrame['Age'] = dataFrame['Age'].astype(int)
dataFrame['Age']
# Out:
# 0      34
# 1      47
# 2      62
# 3      27
# 4      22
#        ..
# 413    30
# 414    39
# 415    38
# 416    30
# 417    30
# Name: Age, Length: 418, dtype: int64

# %% [markdown]
# ### **How many passengers survived and how many were killed (in number and %)**

# %%
Total_survived= dataFrame[['Survived', 'PassengerId']]   
ds= Total_survived.groupby(['Survived'])

# %% [markdown]
# ##### Survived & Killed In **Numbers**

# %%
total_survived_in_Number = ds.count()
total_survived_in_Number
# Out:
#           PassengerId
# Survived
# 0                 266
# 1                 152

# %% [markdown]
# #### Killed In **Percent**

# %%
total_killed_in_Percent = (total_survived_in_Number['PassengerId'][0]/total_survived_in_Number['PassengerId'].sum())*100
print('Total',total_killed_in_Percent.round(), '% were killed in Titanic.')
# Out:
# Total 64.0 % were killed in Titanic.

# %% [markdown]
# #### Survived In **Percent**

# %%
total_survived_in_Percent = (total_survived_in_Number['PassengerId'][1]/total_survived_in_Number['PassengerId'].sum())*100
print('Total',total_survived_in_Percent.round(), '% were Survived in Titanic.')
# Out:
# Total 36.0 % were Survived in Titanic.

# %% [markdown]
# ### **Does survival had anything to do with the gender? (Survival vs Gender)**

# %%
Total_survived_gender= dataFrame[['Survived', 'Sex']]   
Total_survived_gender= Total_survived_gender.groupby(['Sex'],as_index = False)

# %%
Total_survived_gender = Total_survived_gender.count()
Total_survived_gender.head()
# Out:
#       Sex  Survived
# 0  female       152
# 1    male       266

# %% [markdown]
# #### **Survived Male**

# %%
print('Total' ,Total_survived_gender['Survived'][1],'Male was survived.')
# Out:
# Total 266 Male was survived.

# %% [markdown]
# #### **Survived Female**

# %%
print('Total' ,Total_survived_gender['Survived'][0],'Female was survived.')
# Out:
# Total 152 Female was survived.

# %% [markdown]
# ### **Does survival have anything to do with the class in which the passenger was traveling and who survived more 1st class passengers, 2nd class passengers or 3rd class passengers?**

# %%
Total_survived_class= dataFrame[['Survived', 'Pclass']]   
Total_survived_class= Total_survived_class.groupby(['Pclass'],as_index = False)

# %%
Total_survived_class = Total_survived_class.count()
Total_survived_class
# Out:
#    Pclass  Survived
# 0       1       107
# 1       2        93
# 2       3       218

# %% [markdown]
# ### **Which age group, survived the most, kids (0-12), teen agers (13-19), youngsters (20-30), middle age people (31-50) or elders (50 and) greater) ?**

# %%
Total_survived_age= dataFrame[['Survived', 'Age']]   
Total_survived_age= Total_survived_age.groupby(['Age'],as_index = False)

# %%
Total_survived_age = Total_survived_age.count()
Total_survived_age
# Out:
#     Age  Survived
# 0     0         5
# 1     1         3
# 2     2         2
# 3     3         1
# 4     5         1
# ..  ...       ...
# 59   62         1
# 60   63         2
# 61   64         3
# 62   67         1
# 63   76         1
#
# [64 rows x 2 columns]

# %% [markdown]
# #### Total Survived **Kids**

# %%
Total_survived_kidz = Total_survived_age[Total_survived_age["Age"].between(0, 12)]
Total_survived_kidz = Total_survived_kidz['Age'].count()
print('Total ',Total_survived_kidz, 'Kids with age group Of ( 0 to 12 ) was survived.')
# Out:
# Total  12 Kids with age group Of ( 0 to 12 ) was survived.

# %% [markdown]
# #### Total Survived **Teen Agers**

# %%
Total_survived_teen = Total_survived_age[Total_survived_age["Age"].between(13, 19)]
Total_survived_teen = Total_survived_teen['Age'].count()
print('Total ',Total_survived_teen, 'teen agers with age group Of ( 13 to 19 ) was survived.')
# Out:
# Total  7 teen agers with age group Of ( 13 to 19 ) was survived.

# %% [markdown]
# #### Total Survived **Youngsters**

# %%
Total_survived_youngs = Total_survived_age[Total_survived_age["Age"].between(20, 30)]
Total_survived_youngs = Total_survived_youngs['Age'].count()
print('Total ',Total_survived_youngs, 'youngsters with age group Of ( 20 to 30 ) was survived.')
# Out:
# Total  11 youngsters with age group Of ( 20 to 30 ) was survived.

# %% [markdown]
# #### Total Survived **Middle Age**

# %%
Total_survived_middle = Total_survived_age[Total_survived_age["Age"].between(31, 50)]
Total_survived_middle = Total_survived_middle['Age'].count()
print('Total ',Total_survived_middle, 'middle age with age group Of ( 31 to 50 ) was survived.')
# Out:
# Total  20 middle age with age group Of ( 31 to 50 ) was survived.

# %% [markdown]
# #### Total Survived **Elders**

# %%
Total_survived_elder = Total_survived_age[Total_survived_age["Age"] > 50]
Total_survived_elder = Total_survived_elder['Age'].count()
print('Total ',Total_survived_elder, 'elders with age group Of ( 50 or greater ) was survived.')
# Out:
# Total  14 elders with age group Of ( 50 or greater ) was survived.

# %% [markdown]
# ### **Which people survived the most, either those who were traveling with the family or those who were traveling alone?**

# %%
Total_traveling= dataFrame[[ 'Survived','SibSp']]   
Total_traveling= Total_traveling.groupby(['SibSp'],as_index = False)
Total_traveling = Total_traveling.count()
Total_traveling
# Out:
#    SibSp  Survived
# 0      0       283
# 1      1       110
# 2      2        14
# 3      3         4
# 4      4         4
# 5      5         1
# 6      8         2

# %% [markdown]
# #### **Traveling Alone**

# %%
print('Total',Total_traveling['Survived'][0],'peoples was survived who were travelling alone.')
# Out:
# Total 283 peoples was survived who were travelling alone.

# %% [markdown]
# #### **Traveling With Family**

# %%
Total_family = Total_traveling.drop(labels=0, axis=0)
Total_family = Total_family.sum()
Total_family
# Out:
# SibSp        23
# Survived    135
# dtype: int64

# %%
print('Total',Total_family['Survived'],'peoples was survived who were travelling with family.')
# Out:
# Total 135 peoples was survived who were travelling with family.

# %% [markdown]
# ### **Finally compare the survival rate vs gender, class, age group, and family**

# %% [markdown]
# ### **Survival Rate VS Gender**

# %% [markdown]
# #### **Male Survival Rate**

# %%
survival_rate_male = Total_survived_gender['Survived'][0]/ Total_survived_gender['Survived'].sum()
print('Male Survival Rate : ',survival_rate_male)
# Out:
# Male Survival Rate :  0.36363636363636365

# %% [markdown]
# #### **Female Survival Rate**

# %%
survival_rate_female = Total_survived_gender['Survived'][1]/ Total_survived_gender['Survived'].sum()
print('Female Survival Rate : ',survival_rate_female)
# Out:
# Female Survival Rate :  0.6363636363636364

# %% [markdown]
# ### **Survival Rate VS Class**

# %% [markdown]
# #### **First Class Survival Rate**

# %%
survival_rate_class_1 = Total_survived_class['Survived'][0]/ Total_survived_class['Survived'].sum()
print('First Class Survival Rate : ',survival_rate_class_1)
# Out:
# First Class Survival Rate :  0.25598086124401914

# %% [markdown]
# #### **Second Class Survival Rate**

# %%
survival_rate_class_2 = Total_survived_class['Survived'][1]/ Total_survived_class['Survived'].sum()
print('Second Class Survival Rate : ',survival_rate_class_2)
# Out:
# Second Class Survival Rate :  0.22248803827751196

# %% [markdown]
# #### **Third Class Survival Rate**

# %%
survival_rate_class_3 = Total_survived_class['Survived'][2]/ Total_survived_class['Survived'].sum()
print('Third Class Survival Rate : ',survival_rate_class_3)
# Out:
# Third Class Survival Rate :  0.5215311004784688

# %% [markdown]
# ### **Survival Rate VS Age Group**

# %% [markdown]
# #### **Kids Survival Rate**

# %%
survival_rate_kidz = Total_survived_kidz/Total_survived_age['Age'].count()
print('Kids Survival Rate : ',survival_rate_kidz)
# Out:
# Kids Survival Rate :  0.1875

# %% [markdown]
# #### **Teen Agers Survival Rate**

# %%
survival_rate_teen = Total_survived_teen/Total_survived_age['Age'].count()
print('Teen Agers Survival Rate : ',survival_rate_teen)
# Out:
# Teen Agers Survival Rate :  0.109375

# %% [markdown]
# #### **Youngsters Survival Rate**

# %%
survival_rate_youngs = Total_survived_youngs/Total_survived_age['Age'].count()
print('Youngsters Survival Rate : ',survival_rate_youngs)
# Out:
# Youngsters Survival Rate :  0.171875

# %% [markdown]
# #### **MIddle Age Survival Rate**

# %%
survival_rate_middle = Total_survived_middle/Total_survived_age['Age'].count()
print('Middle Agers Survival Rate : ',survival_rate_middle)
# Out:
# Middle Agers Survival Rate :  0.3125

# %% [markdown]
# #### **Elders Survival Rate**

# %%
survival_rate_elders = Total_survived_elder/Total_survived_age['Age'].count()
print('Elders Survival Rate : ',survival_rate_elders)
# Out:
# Elders Survival Rate :  0.21875

# %% [markdown]
# ### **Survival Rate VS Family**

# %% [markdown]
# #### **Family Survival Rate**

# %%
Survival_rate_family = Total_family['Survived']/Total_traveling['Survived'].sum()
print('Family Survival Rate : ',Survival_rate_family)
# Out:
# Family Survival Rate :  0.3229665071770335

# %% [markdown]
# #### **Alone Survival Rate**

# %%
Survival_rate_alone = Total_traveling['Survived'][0]/Total_traveling['Survived'].sum()
print('Without Family Survival Rate : ',Survival_rate_alone)
# Out:
# Without Family Survival Rate :  0.6770334928229665
